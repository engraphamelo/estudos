# %%
import pandas as pd

# %%
data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df=pd.DataFrame(data, list('321'), list('ZYX'))
df
# Out:
#    Z  Y  X
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %%
df.sort_index(inplace=True)
df
# Out:
#    Z  Y  X
# 1  7  8  9
# 2  4  5  6
# 3  1  2  3

# %%
df.sort_index(inplace=True, axis=1)
df
# Out:
#    X  Y  Z
# 1  9  8  7
# 2  6  5  4
# 3  3  2  1

# %%
df.sort_values(by='X', inplace=True) # aqui é possível realizar o sort com mais de uma variável 
df
# Out:
#    X  Y  Z
# 3  3  2  1
# 2  6  5  4
# 1  9  8  7

# %%
df.sort_values(by='3', axis=1, inplace=True)
df
# Out:
#    Z  Y  X
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %% [markdown]
# Continuação do curso Pandas para Data Science Alura

# %%
aluguel=pd.read_csv('aluguel.csv', sep=';')

# %%
aluguel.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
residencial = ['Quitinete', 
'Casa',
'Apartamento',
'Casa de Condomínio',
'Casa de Vila']

# %%
selecao = aluguel['Tipo'].isin(residencial)

# %%
dados_residencial = aluguel[selecao]

# %%
dados_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
list(dados_residencial['Tipo'].drop_duplicates())
# Out:
# ['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Casa de Vila']

# %%
dados_residencial.shape
# Out:
# (22580, 9)

# %%
dados_residencial.index = range(dados_residencial.shape[0])

# %%
dados_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %%
dados_residencial.to_csv('aluguel_residencial.csv', sep = ';')
# aqui vem com dois índices, daí é necessário dropar um index

# %%
df2=pd.read_csv('aluguel_residencial.csv', sep=';')
df2
# Out:
#        Unnamed: 0         Tipo                Bairro  Quartos  Vagas  Suites  \
# 0               0    Quitinete            Copacabana        1      0       0
# 1               1         Casa       Jardim Botânico        2      0       1
# 2               2  Apartamento                Centro        1      0       0
# 3               3  Apartamento          Higienópolis        1      0       0
# 4               4  Apartamento          Vista Alegre        3      1       0
# ...           ...          ...                   ...      ...    ...     ...
# 22575       22575  Apartamento                 Méier        2      0       0
# 22576       22576    Quitinete                Centro        0      0       0
# 22577       22577  Apartamento           Jacarepaguá        3      1       2
# 22578       22578  Apartamento  São Francisco Xavier        2      1       0
# 22579       22579  Apartamento                Leblon        2      0       0
#
#        Area   Valor  Condominio  IPTU
# ...

# %%
dados_residencial.to_csv('aluguel_residencial.csv',sep=';',index=False)

# %%
aluguel_residencial=pd.read_csv('aluguel_residencial.csv',sep=';')

# %%
aluguel_residencial.head()
#apresentado com um único index
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# 4         NaN   NaN

# %%
selecao=aluguel_residencial['Tipo']=='Apartamento' #criou um objeto para selecionar
n1=aluguel_residencial[selecao] #aplicou o selecionador ao dataframe
n1.head(10) #apresentaou o dataframe
# Out:
#            Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 2   Apartamento                   Centro        1      0       0    15
# 3   Apartamento             Higienópolis        1      0       0    48
# 4   Apartamento             Vista Alegre        3      1       0    70
# 5   Apartamento                 Cachambi        2      0       0    50
# 8   Apartamento                   Centro        1      0       0    36
# 9   Apartamento                   Grajaú        2      1       0    70
# 10  Apartamento      Lins de Vasconcelos        3      1       1    90
# 11  Apartamento               Copacabana        1      0       1    40
# 13  Apartamento               Copacabana        4      3       1   243
# 15  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54
#
#       Valor  Condominio   IPTU
# 2     800.0       390.0   20.0
# 3     800.0       230.0    NaN
# 4    1200.0         NaN    NaN
# 5    1300.0       301.0   17.0
# ...

# %%
# para definir a presença de apartamentos vamos empregar a função shape
n1.shape[0] #esta é a quantidade de apartamentos para alugar
# Out:
# 19532

# %%
selecao2=(aluguel_residencial['Tipo']=='Casa') | (aluguel_residencial['Tipo'] == 'Casa de Vila') | (aluguel_residencial['Tipo'] == 'Casa de Condomínio')
n2=aluguel_residencial[selecao2] #quando a selecao for de multiplos valores as condicoes devem estar entre parenteses
n2.head(10)
# Out:
#                   Tipo                   Bairro  Quartos  Vagas  Suites  Area  \
# 1                 Casa          Jardim Botânico        2      0       1   100
# 6   Casa de Condomínio          Barra da Tijuca        5      4       5   750
# 7   Casa de Condomínio                    Ramos        2      2       0    65
# 14  Casa de Condomínio                  Taquara        3      1       1   115
# 18  Casa de Condomínio          Barra da Tijuca        4      3       2   466
# 24                Casa             Campo Grande        4      1       2   400
# 44  Casa de Condomínio          Barra da Tijuca        5     10       5  1600
# 56                Casa                    Méier        2      0       0    51
# 60                Casa              São Conrado        4      2       4   730
# 61  Casa de Condomínio  Freguesia (Jacarepaguá)        5      3       1   140
#
#       Valor  Condominio     IPTU
# 1    7000.0         NaN      NaN
# 6   22000.0         NaN      NaN
# ...

# %%
n2.shape[0] #esta é a quantidade de imoveis casa para alugar
# Out:
# 2212

# %%
selecao3=(aluguel_residencial['Area']>=60) & (aluguel_residencial['Area']<=100)
n3=aluguel_residencial[selecao3]
n3.head(10)
# Out:
#                   Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 1                 Casa      Jardim Botânico        2      0       1   100
# 4          Apartamento         Vista Alegre        3      1       0    70
# 7   Casa de Condomínio                Ramos        2      2       0    65
# 9          Apartamento               Grajaú        2      1       0    70
# 10         Apartamento  Lins de Vasconcelos        3      1       1    90
# 16         Apartamento      Barra da Tijuca        2      1       1    67
# 19         Apartamento               Olaria        3      1       0    68
# 20         Apartamento               Tijuca        2      1       0    78
# 25         Apartamento             Botafogo        2      1       0    76
# 32         Apartamento      Barra da Tijuca        3      1       2    70
#
#      Valor  Condominio   IPTU
# 1   7000.0         NaN    NaN
# 4   1200.0         NaN    NaN
# 7   1000.0         NaN    NaN
# ...

# %%
n3.shape[0] #quantidade de imoveis que tem mais de 60 e menos de 100 metros2
# Out:
# 8719

# %%
selecao4=(aluguel_residencial['Quartos']>=4) & (aluguel_residencial['Valor']<2000)
n4=aluguel_residencial[selecao4]
n4.head()
# Out:
#              Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 484   Apartamento  Recreio dos Bandeirantes        4      2       2   160
# 1003  Apartamento                   Taquara        4      1       1   110
# 1961         Casa              Campo Grande        4      1       4   100
# 2102         Casa         Engenho de Dentro        4      3       0   120
# 2200  Apartamento  Recreio dos Bandeirantes        4      2       2   125
#
#        Valor  Condominio  IPTU
# 484   1900.0       830.0   NaN
# 1003  1900.0         NaN   NaN
# 1961  1600.0         NaN   NaN
# 2102  1500.0         NaN   NaN
# 2200  1700.0         NaN  90.0

# %%
n4.shape[0] #Quantidade de imoveis que atendem
# Out:
# 41

# %% [markdown]
# Exercícios

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
selecap_ex=alunos['Aprovado']==True
aprovados=alunos[selecap_ex]
aprovados.head()
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 0    Ary     15    M    7.5      True
# 3   Beto     32    M   10.0      True
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
selecap_ex2=(alunos['Sexo']=='F')&(alunos['Aprovado']==True)
aprovadas=alunos[selecap_ex2]
aprovadas
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 4  Bruna     42    F    8.2      True
# 5   Dara     21    F    7.0      True

# %%
selecap_ex3=(alunos['Idade']<20)&(alunos['Aprovado']>10)|(alunos['Idade']>=40)
alunos_por_idade=alunos[selecap_ex3]
alunos_por_idade
# Out:
#     Nome  Idade Sexo  Notas  Aprovado
# 2  Denis     56    M    5.0     False
# 4  Bruna     42    F    8.2      True

# %%
selecao5=alunos['Aprovado']==False
reprovados=alunos[selecao5]
reprovados[['Nome','Sexo','Idade']]
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %%
#tambem pode ser resolvido como
reprovados=alunos.loc[selecao5,['Nome','Sexo','Idade']]
reprovados
# Out:
#      Nome Sexo  Idade
# 1   Cátia    F     27
# 2   Denis    M     56
# 6  Carlos    M     19
# 7   Alice    F     35

# %% [markdown]
# Tratando dados

# %%
aluguel_residencial.head(50)
# Out:
#                   Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0            Quitinete                Copacabana        1      0       0
# 1                 Casa           Jardim Botânico        2      0       1
# 2          Apartamento                    Centro        1      0       0
# 3          Apartamento              Higienópolis        1      0       0
# 4          Apartamento              Vista Alegre        3      1       0
# 5          Apartamento                  Cachambi        2      0       0
# 6   Casa de Condomínio           Barra da Tijuca        5      4       5
# 7   Casa de Condomínio                     Ramos        2      2       0
# 8          Apartamento                    Centro        1      0       0
# 9          Apartamento                    Grajaú        2      1       0
# 10         Apartamento       Lins de Vasconcelos        3      1       1
# 11         Apartamento                Copacabana        1      0       1
# ...

# %%
aluguel_residencial.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 22575  False   False    False  False   False  False  False       False  False
# 22576  False   False    False  False   False  False  False       False  False
# 22577  False   False    False  False   False  False  False       False  False
# 22578  False   False    False  False   False  False  False       False  False
# 22579  False   False    False  False   False  False  False       False   True
#
# [22580 rows x 9 columns]

# %%
aluguel_residencial.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 22575  True    True     True   True    True  True   True        True   True
# 22576  True    True     True   True    True  True   True        True   True
# 22577  True    True     True   True    True  True   True        True   True
# 22578  True    True     True   True    True  True   True        True   True
# 22579  True    True     True   True    True  True   True        True  False
#
# [22580 rows x 9 columns]

# %%
aluguel_residencial.info() #conferindo o tamanho do DF com a contagem dos não nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22580 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        22580 non-null  object
#  1   Bairro      22580 non-null  object
#  2   Quartos     22580 non-null  int64
#  3   Vagas       22580 non-null  int64
#  4   Suites      22580 non-null  int64
#  5   Area        22580 non-null  int64
#  6   Valor       22571 non-null  float64
#  7   Condominio  20765 non-null  float64
#  8   IPTU        15795 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
aluguel_residencial[aluguel_residencial['Valor'].isnull()]
# Out:
#              Tipo           Bairro  Quartos  Vagas  Suites  Area  Valor  \
# 58    Apartamento  Barra da Tijuca        2      1       1    70    NaN
# 1492  Apartamento             Leme        2      0       0    75    NaN
# 1683         Casa     Campo Grande        3      4       3   363    NaN
# 2012  Apartamento         Botafogo        2      0       0    95    NaN
# 2034  Apartamento       Copacabana        2      0       0    72    NaN
# 4941         Casa     Campo Grande        3      2       1   100    NaN
# 8568  Apartamento             Leme        2      0       1    75    NaN
# 8947  Apartamento           Glória        3      0       1   135    NaN
# 9149  Apartamento            Gávea        3      1       1   105    NaN
#
#       Condominio   IPTU
# 58         970.0   68.0
# 1492       878.0    NaN
# 1683         NaN    NaN
# 2012      1010.0  170.0
# 2034       850.0    NaN
# 4941         NaN    NaN
# 8568       878.0    NaN
# 8947       910.0  228.0
# ...

# %%
A=aluguel_residencial.shape[0]
aluguel_residencial.dropna(subset=['Valor'],inplace=True) #retirando valores nulos
B=aluguel_residencial.shape[0]
A-B
# Out:
# 9

# %%
# quantidade de registros nulos
aluguel_residencial[aluguel_residencial['Condominio'].isnull()].shape[0]
# Out:
# 1813

# %%
aluguel_residencial[aluguel_residencial['Condominio'].isnull()].shape[0]
# Out:
# 1813

# %%
selecao6=(aluguel_residencial['Tipo']=='Apartamento')&(aluguel_residencial['Condominio'].isnull())

# %%
A=aluguel_residencial.shape[0]
aluguel_residencial=aluguel_residencial[~selecao6]
B=aluguel_residencial.shape[0]
A-B
# Out:
# 745

# %%
aluguel_residencial[aluguel_residencial['Condominio'].isnull()].shape[0]
# Out:
# 1068

# %%
aluguel_residencial.fillna(0, inplace=True)

# %%
aluguel_residencial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21826 entries, 0 to 22579
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        21826 non-null  object
#  1   Bairro      21826 non-null  object
#  2   Quartos     21826 non-null  int64
#  3   Vagas       21826 non-null  int64
#  4   Suites      21826 non-null  int64
#  5   Area        21826 non-null  int64
#  6   Valor       21826 non-null  float64
#  7   Condominio  21826 non-null  float64
#  8   IPTU        21826 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
# esta forma também pode resolver o fillna implícito
# aluguel_residencial=aluguel_residencial.fillna({'Condomínio':0,'IPTU':0})

# %%
aluguel_residencial.to_csv('aluguel_residencial.csv', sep=';', index=False)

# %% [markdown]
# Exercício

# %%
data = [0.5, None, None, 0.52, 0.54, None, None, 0.59, 0.6, None, 0.7]
s = pd.Series(data)

# %%
s
# Out:
# 0     0.50
# 1      NaN
# 2      NaN
# 3     0.52
# 4     0.54
# 5      NaN
# 6      NaN
# 7     0.59
# 8     0.60
# 9      NaN
# 10    0.70
# dtype: float64

# %%
s.fillna(method='ffill') #completa com os valores anteriores a partir dos anteriores superiores
# Out:
# 0     0.50
# 1     0.50
# 2     0.50
# 3     0.52
# 4     0.54
# 5     0.54
# 6     0.54
# 7     0.59
# 8     0.60
# 9     0.60
# 10    0.70
# dtype: float64

# %%
s.fillna(method='bfill') #completa com os valores anteriores a partir dos anteriores inferiores
# o argumento aceita um limite após o método, limit=1
# Out:
# 0     0.50
# 1     0.52
# 2     0.52
# 3     0.52
# 4     0.54
# 5     0.59
# 6     0.59
# 7     0.59
# 8     0.60
# 9     0.70
# 10    0.70
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0     0.500
# 1     0.575
# 2     0.575
# 3     0.520
# 4     0.540
# 5     0.575
# 6     0.575
# 7     0.590
# 8     0.600
# 9     0.575
# 10    0.700
# dtype: float64

# %%
s.fillna(s.median())
# Out:
# 0     0.500
# 1     0.565
# 2     0.565
# 3     0.520
# 4     0.540
# 5     0.565
# 6     0.565
# 7     0.590
# 8     0.600
# 9     0.565
# 10    0.700
# dtype: float64

# %%
aluguel_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         0.0   0.0
# 2       390.0  20.0
# 3       230.0   0.0
# 5       301.0  17.0

# %%
aluguel_residencial['Valor Bruto']=(aluguel_residencial['Valor']+aluguel_residencial['Condominio']+aluguel_residencial['IPTU']).round(2)
aluguel_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto
# 0       500.0  60.0       2260.0
# 1         0.0   0.0       7000.0
# 2       390.0  20.0       1210.0
# 3       230.0   0.0       1030.0
# 5       301.0  17.0       1618.0

# %%
aluguel_residencial['Valor bruto por m2']=(aluguel_residencial['Valor Bruto']/aluguel_residencial['Area']).round(2)
aluguel_residencial.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto  Valor bruto por m2 Tipo Agregado
# 0       500.0  60.0       2260.0               56.50   Apartamento
# 1         0.0   0.0       7000.0               70.00          Casa
# 2       390.0  20.0       1210.0               80.67   Apartamento
# 3       230.0   0.0       1030.0               21.46   Apartamento
# 5       301.0  17.0       1618.0               32.36   Apartamento

# %%
casa=['Casa','Casa de Condomínio','Casa de Vila']

# %%
aluguel_residencial['Tipo Agregado']=aluguel_residencial['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
aluguel_residencial.head(50)
# Out:
#                   Tipo                    Bairro  Quartos  Vagas  Suites  \
# 0            Quitinete                Copacabana        1      0       0
# 1                 Casa           Jardim Botânico        2      0       1
# 2          Apartamento                    Centro        1      0       0
# 3          Apartamento              Higienópolis        1      0       0
# 5          Apartamento                  Cachambi        2      0       0
# 6   Casa de Condomínio           Barra da Tijuca        5      4       5
# 7   Casa de Condomínio                     Ramos        2      2       0
# 9          Apartamento                    Grajaú        2      1       0
# 10         Apartamento       Lins de Vasconcelos        3      1       1
# 11         Apartamento                Copacabana        1      0       1
# 12           Quitinete                Copacabana        1      0       0
# 13         Apartamento                Copacabana        4      3       1
# ...

# %%
# Excluindo variáveis do dataframe

# %%
dados_aux=pd.DataFrame(aluguel_residencial[['Tipo Agregado','Valor Bruto','Valor bruto por m2']])

# %%
dados_aux.head(10)
# Out:
#    Tipo Agregado  Valor Bruto  Valor bruto por m2
# 0    Apartamento       2260.0               56.50
# 1           Casa       7000.0               70.00
# 2    Apartamento       1210.0               80.67
# 3    Apartamento       1030.0               21.46
# 5    Apartamento       1618.0               32.36
# 6           Casa      22000.0               29.33
# 7           Casa       1000.0               15.38
# 9    Apartamento       2216.0               31.66
# 10   Apartamento       1969.0               21.88
# 11   Apartamento       2611.0               65.28

# %%
del dados_aux['Valor Bruto']

# %%
dados_aux.head(10)
# Out:
#    Tipo Agregado  Valor bruto por m2
# 0    Apartamento               56.50
# 1           Casa               70.00
# 2    Apartamento               80.67
# 3    Apartamento               21.46
# 5    Apartamento               32.36
# 6           Casa               29.33
# 7           Casa               15.38
# 9    Apartamento               31.66
# 10   Apartamento               21.88
# 11   Apartamento               65.28

# %%
dados_aux.pop('Valor bruto por m2')
# Out:
# 0        56.50
# 1        70.00
# 2        80.67
# 3        21.46
# 5        32.36
#          ...
# 22575    20.54
# 22576    43.52
# 22577    33.85
# 22578    40.54
# 22579    53.71
# Name: Valor bruto por m2, Length: 21826, dtype: float64

# %%
dados_aux
# Out:
#       Tipo Agregado
# 0       Apartamento
# 1              Casa
# 2       Apartamento
# 3       Apartamento
# 5       Apartamento
# ...             ...
# 22575   Apartamento
# 22576   Apartamento
# 22577   Apartamento
# 22578   Apartamento
# 22579   Apartamento
#
# [21826 rows x 1 columns]

# %%
aluguel_residencial.drop(['Valor Bruto', 'Valor bruto por m2'], axis=1, inplace=True)

# %%
aluguel_residencial.head(10)
# Out:
#                   Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete           Copacabana        1      0       0    40
# 1                 Casa      Jardim Botânico        2      0       1   100
# 2          Apartamento               Centro        1      0       0    15
# 3          Apartamento         Higienópolis        1      0       0    48
# 5          Apartamento             Cachambi        2      0       0    50
# 6   Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 7   Casa de Condomínio                Ramos        2      2       0    65
# 9          Apartamento               Grajaú        2      1       0    70
# 10         Apartamento  Lins de Vasconcelos        3      1       1    90
# 11         Apartamento           Copacabana        1      0       1    40
#
#       Valor  Condominio  IPTU Tipo Agregado
# 0    1700.0       500.0  60.0   Apartamento
# 1    7000.0         0.0   0.0          Casa
# ...

# %%
aluguel_residencial.to_csv('aluguel_residencial_2.csv',sep=';',index=False) #salvando arquivos em um CSV

# %% [markdown]
# Extras do curso Alura

# %%
s=pd.Series(list('asdadedadesdassdasdes'))
s

# %%
s.unique()

# %%
s.value_counts()

# %%
dados=pd.read_csv('aluguel_residencial_2.csv', sep=';')

# %%
dados.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio',
#        'Casa de Vila'], dtype=object)

# %%
dados.Tipo.value_counts()
# Out:
# Tipo
# Apartamento           18780
# Casa de Condomínio      996
# Casa                    965
# Quitinete               836
# Casa de Vila            249
# Name: count, dtype: int64

# %% [markdown]
# Exeercício

# %%
m1 = 'CCcCCccCCCccCcCccCcCcCCCcCCcccCCcCcCcCcccCCcCcccCc'
m2 = 'CCCCCccCccCcCCCCccCccccCccCccCCcCccCcCcCCcCccCccCc'
m3 = 'CccCCccCcCCCCCCCCCCcccCccCCCCCCccCCCcccCCCcCCcccCC'
m4 = 'cCCccCCccCCccCCccccCcCcCcCcCcCcCCCCccccCCCcCCcCCCC'
m5 = 'CCCcCcCcCcCCCcCCcCcCCccCcCCcccCccCCcCcCcCcCcccccCc'

# %%
eventos={'m1': list(m1),
         'm2': list(m2),
         'm3': list(m3),
         'm4': list(m4),
         'm5': list(m5),}

moedas=pd.DataFrame(eventos)
moedas.head(5)
# Out:
#   m1 m2 m3 m4 m5
# 0  C  C  C  c  C
# 1  C  C  c  C  C
# 2  c  C  c  C  C
# 3  C  C  C  c  c
# 4  C  C  C  c  C

# %%
df=pd.DataFrame(data=['Cara','Coroa'],
                index=['c', 'C'],
                columns=['Faces'])
df
# Out:
#    Faces
# c   Cara
# C  Coroa

# %%
for item in moedas:
    df=pd.concat([df, moedas[item].value_counts()],axis=1)

df
# Out:
#    Faces  count  count  count  count  count
# c   Cara     25     26     19     23     25
# C  Coroa     25     24     31     27     25

# %% [markdown]
# Voltando ao curso

# %%
dados=pd.read_csv('aluguel_residencial_2.csv',sep=';')
dados.head(5)
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor por m2 Tipo Agregado
# 0       500.0  60.0         42.50   Apartamento
# 1         0.0   0.0         70.00          Casa
# 2       390.0  20.0         53.33   Apartamento
# 3       230.0   0.0         16.67   Apartamento
# 4       301.0  17.0         26.00   Apartamento

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0          Copacabana
# 5     Barra da Tijuca
# 15             Tijuca
# 19            Ipanema
# 23           Botafogo
# 27             Leblon
# 78           Flamengo
# Name: Bairro, dtype: object

# %%
grupo_bairro=dados.groupby('Bairro')

# %%
grupo_bairro

# %%
for bairro, dados in grupo_bairro:
    print(bairro)
# Out:
# Barra da Tijuca
# Botafogo
# Copacabana
# Flamengo
# Ipanema
# Leblon
# Tijuca

# %%
for bairro, data in grupo_bairro:
    print('{}->{}'.format(bairro,data.Valor.mean()))
# Out:
# Barra da Tijuca->7069.552938130986
# Botafogo->8791.828178694159
# Copacabana->4126.677004538578
# Flamengo->4113.526610644258
# Ipanema->9352.001133786847
# Leblon->8746.344992050874
# Tijuca->2043.52

# %%
grupo_bairro['Valor'].mean()
# Out:
# Bairro
# Barra da Tijuca    7069.552938
# Botafogo           8791.828179
# Copacabana         4126.677005
# Flamengo           4113.526611
# Ipanema            9352.001134
# Leblon             8746.344992
# Tijuca             2043.520000
# Name: Valor, dtype: float64

# %%
grupo_bairro[['Valor','Condominio']].mean().round(2) #maneira mais simples e adequada
# Out:
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  7069.55     3591.01
# Botafogo         8791.83      976.28
# Copacabana       4126.68     1148.68
# Flamengo         4113.53     1102.15
# Ipanema          9352.00     2244.44
# Leblon           8746.34     2107.18
# Tijuca           2043.52      711.69

# %% [markdown]
# Exercício

# %%
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %%
sexo=alunos.groupby('Sexo')
sexo

# %%
sexo=pd.DataFrame(sexo['Notas'].mean().round(2))
sexo.columns=['Notas Médias']
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# Voltando a aula: Estatísticas descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count     mean        std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  3863.0  7069.55   11874.15   800.0  2500.0  4500.0   8500.0
# Botafogo          873.0  8791.83  152202.41   700.0  2200.0  3000.0   4350.0
# Copacabana       2644.0  4126.68    3611.41   100.0  2000.0  3000.0   4800.0
# Flamengo          714.0  4113.53    3839.13   800.0  1900.0  2900.0   4975.0
# Ipanema          1764.0  9352.00    8219.72  1200.0  4500.0  7000.0  11000.0
# Leblon           1258.0  8746.34    7004.04   100.0  4500.0  7000.0  10500.0
# Tijuca           1100.0  2043.52    1664.34   750.0  1500.0  1800.0   2300.0
#
#                        max
# Bairro
# Barra da Tijuca   600000.0
# Botafogo         4500000.0
# Copacabana         35000.0
# Flamengo           35000.0
# Ipanema            90000.0
# Leblon            100000.0
# Tijuca             45000.0

# %%
grupo_bairro['Valor'].aggregate(['min','max','sum']).rename(columns={'min':'Mínimo','max':'Máximo','sum':'Soma'})
# Out:
#                  Mínimo     Máximo        Soma
# Bairro
# Barra da Tijuca   800.0   600000.0  27309683.0
# Botafogo          700.0  4500000.0   7675266.0
# Copacabana        100.0    35000.0  10910934.0
# Flamengo          800.0    35000.0   2937058.0
# Ipanema          1200.0    90000.0  16496930.0
# Leblon            100.0   100000.0  11002902.0
# Tijuca            750.0    45000.0   2247872.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure',figsize=(20,10))

# %%
fig=grupo_bairro['Valor'].std().plot.bar(color='blue')

# %%
fig=grupo_bairro['Valor'].mean().plot.bar(color='blue')
fig.set_ylabel('Valor do aluguel')
fig.set_title('Valor médio do aluguel por bairro',{'fontsize':22})
# Out:
# Text(0.5, 1.0, 'Valor médio do aluguel por bairro')

# %% [markdown]
# Exercício proposto

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto', sort = False)
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2

# %%
estatisticas=['mean','std','min','max']
nomes={'mean':'Média','std':'Desvio Padrão','min':'Mínimo','max':'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns=nomes).round(2) #o método aggregate pode ser cimplificado para agg()
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
# Batata    3.96           0.26    3.69     4.2

# %% [markdown]
# Extras do Alura

# %%
# 1 e 2
# 3 e 4
# 5 e 6
# 7 ou mais quartos
classe=[0,2,4,6,100]

# %%
quartos=pd.cut(aluguel_residencial.Quartos,classe)
quartos
# Out:
# 0        (0.0, 2.0]
# 1        (0.0, 2.0]
# 2        (0.0, 2.0]
# 3        (0.0, 2.0]
# 5        (0.0, 2.0]
#             ...
# 22575    (0.0, 2.0]
# 22576           NaN
# 22577    (2.0, 4.0]
# 22578    (0.0, 2.0]
# 22579    (0.0, 2.0]
# Name: Quartos, Length: 21826, dtype: category
# Categories (4, interval[int64, right]): [(0, 2] < (2, 4] < (4, 6] < (6, 100]]

# %%
pd.value_counts(quartos) #frequencia de ocorrencia de moradias com diferentes numeros de quartos
# Out:
# Quartos
# (0, 2]      11250
# (2, 4]       9681
# (4, 6]        686
# (6, 100]       50
# Name: count, dtype: int64

# %%
labels=['1 e 2 quartos','3 e 4 quartos','5 e 6 quartos','7 ou mais quartos']

# %%
quartos=pd.cut(aluguel_residencial.Quartos,classe,labels=labels, include_lowest=True)

# %%
pd.value_counts(quartos)
# Out:
# Quartos
# 1 e 2 quartos        11409
# 3 e 4 quartos         9681
# 5 e 6 quartos          686
# 7 ou mais quartos       50
# Name: count, dtype: int64

# %%
dados=pd.read_csv('aluguel_residencial_2.csv', sep=';')
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor por m2 Tipo Agregado
# 0       500.0  60.0         42.50   Apartamento
# 1         0.0   0.0         70.00          Casa
# 2       390.0  20.0         53.33   Apartamento
# 3       230.0   0.0         16.67   Apartamento
# 4       301.0  17.0         26.00   Apartamento

# %%
fig=dados.boxplot(['Valor'])

# %%
dados[dados['Valor']>=50000]
# Out:
#                      Tipo                    Bairro  Quartos  Vagas  Suites  \
# 121           Apartamento                   Ipanema        4      6       1
# 1220   Casa de Condomínio           Barra da Tijuca        5      8       5
# 2251          Apartamento                   Ipanema        4      6       4
# 4059   Casa de Condomínio           Jardim Botânico        4      6       4
# 4863          Apartamento                   Ipanema        5      3       4
# 4962          Apartamento                   Ipanema        4      1       4
# 5584          Apartamento                    Leblon        4      2       2
# 7629          Apartamento           Barra da Tijuca        1      1       0
# 7673          Apartamento                    Leblon        4      2       2
# 9392          Apartamento                   Ipanema        4      2       2
# 9838          Apartamento                   Ipanema        5      3       4
# ...

# %%
valor=dados['Valor']

# %%
Q1=valor.quantile(.25)
Q3=valor.quantile(.75)
IIQ=Q3-Q1
limite_inferior=(Q1-1.5*IIQ)
limite_superior=(Q3+1.5*IIQ)

# %% [markdown]
# Removendo outliers a partir do boxplot

# %%
selecao=(valor>=limite_inferior) & (valor<=limite_superior)
dados_new=dados[selecao]

# %%
fig=dados_new.boxplot(['Valor'])
#dados_new.hist(['Valor'])

# %% [markdown]
# Exercício proposto

# %%
amostra=pd.read_csv('aluguel_amostra.csv',sep=';')
amostra.head()
# Out:
#           Tipo                    Bairro  Quartos  Vagas  Suites  Area  \
# 0  Apartamento  Recreio dos Bandeirantes        3      2       1   320
# 1  Apartamento                  Maracanã        2      0       0    59
# 2  Apartamento                    Leblon        3      2       1   147
# 3  Apartamento               São Conrado        3      3       3   270
# 4  Apartamento                    Tijuca        2      1       0    65
#
#      Valor  Condominio    IPTU  Valor m2 Tipo Agregado
# 0   3200.0      1319.0     0.0     10.00   Apartamento
# 1    800.0       725.0    47.0     13.56   Apartamento
# 2   7500.0      1000.0   381.0     51.02   Apartamento
# 3  14999.0      2800.0  1200.0     55.55   Apartamento
# 4   1200.0       640.0    97.0     18.46   Apartamento

# %%
valor=amostra['Valor m2']

# %%
q1=valor.quantile(.25).round(2)
q3=valor.quantile(.75).round(2)
iiq=(q3-q1).round(2)
li=(q1-1.5*iiq).round(2)
ls=(q3+1.5*iiq).round(2)
print(f'O primeiro quartil é {q1}\n',
      f'O terceiro quartil é {q3}\n',
      f'O intervalo interquartil é {iiq}\n',
      f'O limite inferior é {li}\n',
      f'O limite superior é {ls}\n')
# Out:
# O primeiro quartil é 21.25
#  O terceiro quartil é 42.31
#  O intervalo interquartil é 21.06
#  O limite inferior é -10.34
#  O limite superior é 73.9

# %%
amostra.boxplot(['Valor'], by = ['Tipo'])
# Out:
# <Axes: title={'center': 'Valor'}, xlabel='[Tipo]'>

# %%
grupo_tipo=amostra.groupby('Tipo')

# %%
grupo_tipo=dados.groupby('Tipo')['Valor']

# %%
q1=grupo_tipo.quantile(.25).round(2)
q3=grupo_tipo.quantile(.75).round(2)
iiq=(q3-q1).round(2)
li=(q1-1.5*iiq).round(2)
ls=(q3+1.5*iiq).round(2)

# %%
q1
# Out:
# Tipo
# Apartamento           1700.0
# Casa                  1100.0
# Casa de Condomínio    4000.0
# Casa de Vila           750.0
# Quitinete              900.0
# Name: Valor, dtype: float64

# %%
q3
# Out:
# Tipo
# Apartamento            5000.0
# Casa                   9800.0
# Casa de Condomínio    15250.0
# Casa de Vila           1800.0
# Quitinete              1500.0
# Name: Valor, dtype: float64

# %%
iiq
# Out:
# Tipo
# Apartamento            3300.0
# Casa                   8700.0
# Casa de Condomínio    11250.0
# Casa de Vila           1050.0
# Quitinete               600.0
# Name: Valor, dtype: float64

# %%
ls
# Out:
# Tipo
# Apartamento            9950.0
# Casa                  22850.0
# Casa de Condomínio    32125.0
# Casa de Vila           3375.0
# Quitinete              2400.0
# Name: Valor, dtype: float64

# %%
li
# Out:
# Tipo
# Apartamento           -3250.0
# Casa                 -11950.0
# Casa de Condomínio   -12875.0
# Casa de Vila           -825.0
# Quitinete                 0.0
# Name: Valor, dtype: float64

# %%
dados.boxplot(['Valor'], by = ['Tipo'])
# Out:
# <Axes: title={'center': 'Valor'}, xlabel='[Tipo]'>

# %%
grupo_tipo = dados.groupby('Tipo')

# %%
grupo_tipo = dados.groupby('Tipo')

# %%
grupo_tipo = dados.groupby('Tipo')['Valor']

# %%
Q1 =  grupo_tipo.quantile(.25)
Q3 =  grupo_tipo.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
limite_superior['Apartamento']
# Out:
# 9950.0

# %%
for tipo in grupo_tipo.groups.keys():
    print(tipo)
# Out:
# Apartamento
# Casa
# Casa de Condomínio
# Casa de Vila
# Quitinete

# %%
for tipo in grupo_tipo.groups.keys():
    eh_tipo = dados['Tipo'] == tipo
    eh_dentro_limite = (dados['Valor'] >= limite_inferior[tipo]) & (dados['Valor'] <= limite_superior[tipo])
    selecao = eh_tipo & eh_dentro_limite
    dados[selecao]

# %%
dados_new = pd.DataFrame()
for tipo in grupo_tipo.groups.keys():
    eh_tipo = dados['Tipo'] == tipo
    eh_dentro_limite = (dados['Valor'] >= limite_inferior[tipo]) & (dados['Valor'] <= limite_superior[tipo])
    selecao = eh_tipo & eh_dentro_limite
    dados_selecao = dados[selecao]
    dados_new = pd.concat([dados_new, dados_selecao])

# %%
dados_new.boxplot(['Valor'], by = ['Tipo'])
# Out:
# <Axes: title={'center': 'Valor'}, xlabel='[Tipo]'>

# %%
dados_new.to_csv('aluguel_residencial_sem_outliers.csv', sep = ';', index = False)

# %%
area=plt.figure()

# %%
g1=area.add_subplot(2,2,1)
g2=area.add_subplot(2,2,2)
g3=area.add_subplot(2,2,3)
g4=area.add_subplot(2,2,4)

# %%
g1.scatter(dados.Valor, dados.Area)
g1.set_title('Valor X Área')
g2.hist(dados.Valor)
g2.set_title('Histograma')
dados_g3=dados.Valor.sample(100)
dados_g3.index=range(dados_g3.shape[0])
g3.plot(dados_g3)
g3.set_title('Amostra(Valor)')
grupo=dados.groupby('Tipo')['Valor']
label=grupo.mean().index
valores=grupo.mean().values
g4.bar(label,valores)
g4.set_title('Valor Médio por tipo')
# Out:
# Text(0.5, 1.0, 'Valor Médio por tipo')

# %%
area

# %%
area.savefig('grafico.png',dpi=300,bbox_inches='tight')

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (15, 7))

dados = pd.read_csv('aluguel_amostra.csv', sep = ';')

# %%
area=plt.figure()
g1=area.add_subplot(1,2,1)
g2=area.add_subplot(1,2,2)
grupo1=dados.groupby('Tipo Agregado')['Valor']
label=grupo1.count().index
valores=grupo1.count().values
g1.pie(valores, labels=label, autopct='%1.1f%%')
g1.set_title('Total de Imóveis por Tipo Agregado')
grupo2=dados.groupby('Tipo')['Valor']
label=grupo2.count().index
valores=grupo2.count().values
g2.pie(valores, labels=label,autopct='%1.1f%%', explode=(.1,.1,.1,.1,.1))
g2.set_title('Total de Imóveis por Tipo')
# Out:
# Text(0.5, 1.0, 'Total de Imóveis por Tipo')

# %%
area.savefig('grafico2.png',dpi=300,bbox_inches='tight')
